# %%
import pandas as pd
import numpy as np

# %%
movies=pd.read_csv('TeluguMovies_dataset.csv')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1400 non-null   int64
#  1   Movie          1400 non-null   object
#  2   Year           1352 non-null   float64
#  3   Certificate    951 non-null    object
#  4   Genre          1389 non-null   object
#  5   Overview       1221 non-null   object
#  6   Runtime        1400 non-null   int64
#  7   Rating         1400 non-null   float64
#  8   No.of.Ratings  1400 non-null   int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 98.6+ KB

# %%
movies.shape
# Out:
# (1400, 9)

# %%
movies.rename(columns={'Year':'year'},inplace=True)

# %%
movies.head(2)
# Out:
#    Unnamed: 0                        Movie    year Certificate  \
# 0           0      Bahubali: The Beginning  2015.0          UA
# 1           1  Baahubali 2: The Conclusion  2017.0          UA
#
#                        Genre  \
# 0  Action, Drama
# 1  Action, Drama
#
#                                             Overview  Runtime  Rating  \
# 0      In ancient India, an adventurous and darin...      159     8.1
# 1      When Shiva, the son of Bahubali, learns ab...      167     8.2
#
#    No.of.Ratings
# 0          99114
# 1          71458

# %%
movies['Movie'][0]
# Out:
# 'Bahubali: The Beginning'

# %%
mov=movies[['Movie','Certificate','Genre','Overview']]

# %%
mov.head(121)
# Out:
#                            Movie Certificate  \
# 0        Bahubali: The Beginning          UA
# 1    Baahubali 2: The Conclusion          UA
# 2                1 - Nenokkadine          UA
# 3                        Dhoom:3          UA
# 4                         Ra.One           U
# ..                           ...         ...
# 116                  Oosaravelli          UA
# 117                        Evaru          UA
# 118                       Odiyan           U
# 119                Khaidi No 150          UA
# 120                          NGK           U
#
#                                      Genre  \
# 0                Action, Drama
# 1                Action, Drama
# 2             Action, Thriller
# 3             Action, Thriller
# 4    Action, Adventure, Sci-Fi
# ..                                     ...
# 116           Action, Thriller
# 117     Crime, Drama, Thriller
# 118     Action, Drama, Fantasy
# 119              Action, Drama
# 120              Action, Drama
#
# ...

# %%
mov['Overview'][0]
# Out:
# '    In ancient India, an adventurous and daring man becomes involved in a decades old feud between two warring people.'

# %%
mov.isnull().sum()
# Out:
# Movie            0
# Certificate    449
# Genre           11
# Overview       179
# dtype: int64

# %%
mov.shape
# Out:
# (1400, 4)

# %%
mov['Certificate'].fillna('UA',inplace=True)
# Out:
# C:\Users\Harshith\anaconda3\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
mov.isnull().sum()
# Out:
# Movie            0
# Certificate      0
# Genre           11
# Overview       179
# dtype: int64

# %%
mov['Genre'].fillna('Drama ,Family',inplace=True)

# %%
mov.isnull().sum()
# Out:
# Movie            0
# Certificate      0
# Genre            0
# Overview       179
# dtype: int64

# %%
mov.shape
# Out:
# (1400, 4)

# %%
mov.dropna(inplace=True)
# Out:
# C:\Users\Harshith\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
mov.shape
# Out:
# (1221, 4)

# %%
mov.tail(10)
# Out:
#                                 Movie Certificate  \
# 1385                Andha Oru Nimidam          UA
# 1386                     Maavichiguru           U
# 1389                      Billa Ranga           A
# 1390                       Vicky Dada           A
# 1391  Kondura (The Sage from the Sea)          UA
# 1392           Money Money More Money          UA
# 1396                         Jakkanna          UA
# 1397                   Muvva Gopaludu          UA
# 1398            Ninney Ishta Paddaanu           U
# 1399                         9 Nelalu           U
#
#                                   Genre  \
# 1385   Action, Crime, Drama
# 1386                  Drama
# 1389  Action, Crime, Family
# 1390          Action, Crime
# 1391                  Drama
# 1392                 Comedy
# 1396          Comedy, Drama
# 1397         Drama, Romance
# 1398                      Drama ,Family
# 1399                  Drama
#
#                                                Overview
# ...

# %%
mov.duplicated().sum()
mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1221 entries, 0 to 1399
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Movie        1221 non-null   object
#  1   Certificate  1221 non-null   object
#  2   Genre        1221 non-null   object
#  3   Overview     1221 non-null   object
# dtypes: object(4)
# memory usage: 47.7+ KB

# %%
type(mov['Overview'])
type(mov['Genre'])
# Out:
# pandas.core.series.Series

# %%
mov['Overview'][0]
# Out:
# '    In ancient India, an adventurous and daring man becomes involved in a decades old feud between two warring people.'

# %%
mov['Overview']=mov['Overview'].apply(lambda x:x.split())
# Out:
# C:\Users\Harshith\AppData\Local\Temp/ipykernel_7100/2429760527.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mov['Overview']=mov['Overview'].apply(lambda x:x.split())

# %%
mov['Overview'][3]
# Out:
# ['When',
#  'Sahir,',
#  'a',
#  'circus',
#  'entertainer',
#  'trained',
#  'in',
#  'magic',
#  'and',
#  'acrobatics,',
#  'turns',
#  'into',
#  'a',
#  'thief',
#  'to',
#  'take',
#  'down',
#  'a',
#  'corrupt',
#  'bank',
#  'in',
#  'Chicago',
#  'that',
#  'ruined',
#  'his',
#  'father,',
#  'Indian',
#  'officers',
#  'Jai',
#  'and',
#  'Ali',
#  'are',
#  'called',
#  'to',
#  'catch',
#  'him.']

# %%
mov['Genre'][0]
# Out:
# 'Action, Drama            '

# %%
mov['Genre']=mov['Genre'].apply(lambda x:x.split())
# Out:
# C:\Users\Harshith\AppData\Local\Temp/ipykernel_7100/3289241495.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mov['Genre']=mov['Genre'].apply(lambda x:x.split())

# %%
mov['Genre'][2]
# Out:
# ['Action,', 'Thriller']

# %%
mov['Genre']=mov['Genre'].apply(lambda x:[i.replace(" ,","")for i in x])
# Out:
# C:\Users\Harshith\AppData\Local\Temp/ipykernel_7100/3753501339.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mov['Genre']=mov['Genre'].apply(lambda x:[i.replace(" ,","")for i in x])

# %%
mov['Genre'][31]
# Out:
# ['Biography,', 'Drama']

# %%
mov['Overview']=mov['Overview'].apply(lambda x:[i.replace(" ","")for i in x])
# Out:
# C:\Users\Harshith\AppData\Local\Temp/ipykernel_7100/126118176.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mov['Overview']=mov['Overview'].apply(lambda x:[i.replace(" ","")for i in x])

# %%
mov['Overview'][3]
# Out:
# ['When',
#  'Sahir,',
#  'a',
#  'circus',
#  'entertainer',
#  'trained',
#  'in',
#  'magic',
#  'and',
#  'acrobatics,',
#  'turns',
#  'into',
#  'a',
#  'thief',
#  'to',
#  'take',
#  'down',
#  'a',
#  'corrupt',
#  'bank',
#  'in',
#  'Chicago',
#  'that',
#  'ruined',
#  'his',
#  'father,',
#  'Indian',
#  'officers',
#  'Jai',
#  'and',
#  'Ali',
#  'are',
#  'called',
#  'to',
#  'catch',
#  'him.']

# %%
mov['tags']=mov['Overview']+mov['Genre']
# Out:
# C:\Users\Harshith\AppData\Local\Temp/ipykernel_7100/2981555350.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mov['tags']=mov['Overview']+mov['Genre']

# %%
mov.head()
# Out:
#                          Movie Certificate                          Genre  \
# 0      Bahubali: The Beginning          UA               [Action,, Drama]
# 1  Baahubali 2: The Conclusion          UA               [Action,, Drama]
# 2              1 - Nenokkadine          UA            [Action,, Thriller]
# 3                      Dhoom:3          UA            [Action,, Thriller]
# 4                       Ra.One           U  [Action,, Adventure,, Sci-Fi]
#
#                                             Overview  \
# 0  [In, ancient, India,, an, adventurous, and, da...
# 1  [When, Shiva,, the, son, of, Bahubali,, learns...
# 2  [A, rock, star, must, overcome, his, psycholog...
# 3  [When, Sahir,, a, circus, entertainer, trained...
# 4  [When, the, titular, antagonist, of, an, actio...
#
#                                                 tags
# 0  [In, ancient, India,, an, adventurous, and, da...
# 1  [When, Shiva,, the, son, of, Bahubali,, learns...
# ...

# %%
movi=mov[['Movie','tags']]

# %%
movi.head(10)
# Out:
#                          Movie  \
# 0      Bahubali: The Beginning
# 1  Baahubali 2: The Conclusion
# 2              1 - Nenokkadine
# 3                      Dhoom:3
# 4                       Ra.One
# 5                      Dhoom:2
# 6                         Eega
# 7                     Krrish 3
# 8                  Arjun Reddy
# 9                 Rangasthalam
#
#                                                 tags
# 0  [In, ancient, India,, an, adventurous, and, da...
# 1  [When, Shiva,, the, son, of, Bahubali,, learns...
# 2  [A, rock, star, must, overcome, his, psycholog...
# 3  [When, Sahir,, a, circus, entertainer, trained...
# 4  [When, the, titular, antagonist, of, an, actio...
# 5  [Mr, A,, a, fearless, thief,, steals, valuable...
# 6  [A, murdered, man, is, reincarnated, as, a, ho...
# 7  [Krrish, and, his, scientist, father, have, to...
# 8  [Arjun, Reddy,, a, short, tempered, house, sur...
# 9  [The, fear, of, his, elder, brother's, death, ...

# %%
movi['tags']=movi['tags'].apply(lambda x:" ".join(x))
# Out:
# C:\Users\Harshith\AppData\Local\Temp/ipykernel_7100/352103785.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movi['tags']=movi['tags'].apply(lambda x:" ".join(x))

# %%
movi['tags'][0]
# Out:
# 'In ancient India, an adventurous and daring man becomes involved in a decades old feud between two warring people. Action, Drama'

# %%
movi['tags']=movi['tags'].apply(lambda x:x.lower())
# Out:
# C:\Users\Harshith\AppData\Local\Temp/ipykernel_7100/1709703994.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movi['tags']=movi['tags'].apply(lambda x:x.lower())

# %%
movi['tags'][2]
# Out:
# "a rock star must overcome his psychological inhibitions to seek revenge for his parents' death. action, thriller"

# %%
len(movi['tags'].values.sum())
# Out:
# 207277

# %%
# converting text to vectors using bag of words technique

from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=2000 , stop_words='english')

# %%
vectors=cv.fit_transform(movi['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
vectors.shape
# Out:
# (1221, 2000)

# %%
cv.get_feature_names()
# Out:
# ['10',
#  '12',
#  '1987',
#  '1988',
#  '20',
#  '2001',
#  '24',
#  '30',
#  'aadi',
#  'abandoned',
#  'abbasi',
#  'abducted',
#  'abhimanyu',
#  'abhiram',
#  'able',
#  'accident',
#  'accidentally',
#  'according',
#  'account',
#  'accused',
#  'acp',
#  'acquire',
#  'act',
#  'acting',
#  'action',
#  'activist',
#  'activities',
#  'actor',
#  'actress',
#  'acts',
#  'actually',
#  'adi',
#  'aditya',
#  'adopted',
#  'adventure',
#  'adventurous',
#  'age',
#  'agency',
#  'agenda',
#  'agent',
#  'ago',
#  'agree',
#  'agrees',
#  'aid',
#  'aide',
#  'aimless',
#  'aishwarya',
#  'ajay',
#  'aka',
#  'akash',
#  'akhil',
#  'akkineni',
#  'akshara',
#  'alcoholic',
#  'alekhya',
#  'ali',
#  'alias',
#  'alike',
#  'alive',
#  'allari',
#  'allegations',
#  'allu',
#  'alongside',
#  'ambition',
#  'america',
#  'american',
#  'amnesia',
#  'amrish',
#  'amrita',
#  'amrutha',
#  'amrutham',
#  'amy',
#  'amyra',
#  'anaamika',
#  'anand',
#  'anasuya',
# ...

# %%
len(cv.get_feature_names())
# Out:
# 2000

# %%
len(cv.get_stop_words())
# Out:
# 318

# %%
import nltk

# %%
# use to convert the words love,loving,loves to love (stemming)
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def stem(text):
    y=[]
    for i in text.split():
        y.append(ps.stem(i))
        
    return " ".join(y)

# %%
ps.stem('doing')
# Out:
# 'do'

# %%
movi['tags']=movi['tags'].apply(stem)
# Out:
# C:\Users\Harshith\AppData\Local\Temp/ipykernel_7100/1813876037.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movi['tags']=movi['tags'].apply(stem)

# %%
movi['tags'].values
# Out:
# array(['in ancient india, an adventur and dare man becom involv in a decad old feud between two war people. action, drama',
#        'when shiva, the son of bahubali, learn about hi heritage, he begin to look for answers. hi stori is juxtapos with past event that unfold in the mahishmati kingdom. action, drama',
#        "a rock star must overcom hi psycholog inhibit to seek reveng for hi parents' death. action, thriller",
#        ...,
#        'muvva gopaludu is a 1987 indian telugu film, direct by kodi ramakrishna and produc by s gopal reddy. the film star bala krishna, vijayashanthi and shobana in lead roles. the music of the film wa compos by k v mahadevan. drama, romanc',
#        'hero charan (tarun) a middl class famili guy, is cheat by sanjana (anitha), a girl from rich family. thi is to take reveng on him as he teas her in the past. when the hero come to ... see full summari » drama ,famili',
# ...

# %%
# check the distance between the vectors by cosine_similarity but not eclide distance(not reccomended)
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
similarity[0]
# Out:
# array([1.        , 0.17407766, 0.09622504, ..., 0.05360563, 0.05661385,
#        0.06154575])

# %%
movi[movi['Movie']=='Arjun Reddy'].index[0]
# Out:
# 8

# %%
sorted(similarity[0],reverse=True)
# Out:
# [1.0000000000000002,
#  0.3849001794597505,
#  0.35355339059327384,
#  0.3333333333333334,
#  0.3333333333333334,
#  0.3273268353539886,
#  0.3273268353539886,
#  0.3273268353539886,
#  0.3202563076101743,
#  0.3086066999241839,
#  0.30618621784789724,
#  0.30618621784789724,
#  0.30151134457776363,
#  0.29814239699997197,
#  0.28867513459481287,
#  0.28867513459481287,
#  0.28867513459481287,
#  0.28867513459481287,
#  0.28867513459481287,
#  0.28867513459481287,
#  0.28867513459481287,
#  0.280056016805602,
#  0.27386127875258315,
#  0.27386127875258315,
#  0.27386127875258315,
#  0.27386127875258315,
#  0.27216552697590873,
#  0.26490647141300877,
#  0.2611164839335468,
#  0.2611164839335468,
#  0.2611164839335468,
#  0.25819888974716115,
#  0.25819888974716115,
#  0.25819888974716115,
#  0.25819888974716115,
#  0.25197631533948484,
#  0.25000000000000006,
#  0.25000000000000006,
#  0.25000000000000006,
#  0.25000000000000006,
#  0.25000000000000006,
#  0.25000000000000006,
# ...

# %%
# function recommd
def recommend(movies):
    movie_index=movi[movi['Movie']==movies].index[0]
    distances=similarity[movie_index]
    movie_list=sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]
    
    for i in movie_list:
        print(movi.iloc[i[0]].Movie)

# %%
movi['Movie'].head(10)
# Out:
# 0        Bahubali: The Beginning
# 1    Baahubali 2: The Conclusion
# 2                1 - Nenokkadine
# 3                        Dhoom:3
# 4                         Ra.One
# 5                        Dhoom:2
# 6                           Eega
# 7                       Krrish 3
# 8                    Arjun Reddy
# 9                   Rangasthalam
# Name: Movie, dtype: object

# %%
recommend('Arjun Reddy')
# Out:
# Lakshyam
# Samarasimha Reddy
# Aadi
# Kumari 21F
# Rx 100

# %%
recommend('Rangasthalam')
# Out:
# Veera
# Tadakha
# Gang Leader
# Kurukshetramu
# Asura

# %%
recommend('Arjun Reddy')
# Out:
# Lakshyam
# Samarasimha Reddy
# Aadi
# Kumari 21F
# Rx 100

# %%
recommend('Eega')
# Out:
# Veera
# Uu Kodathara Ulikki Padathara
# Yamudiki Mogudu
# Yamadonga
# Shadow

# %%
import pickle

# %%
pickle.dump(movi.to_dict(),open('movie_dict.pkl','wb'))

# %%
pickle.dump(similarity,open('similarity.pkl','wb'))
